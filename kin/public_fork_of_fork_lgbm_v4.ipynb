# %%
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s\n\n".format(title, time.time() - t0))

# One-hot encoding for categorical columns with get_dummies
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# Preprocess application_train.csv and application_test.csv
def application_train_test(num_rows = None, nan_as_category = False):
    # Read data and merge
    df = pd.read_csv('../data/application_train.csv', nrows= num_rows)
    test_df = pd.read_csv('../data/application_test.csv', nrows= num_rows)
    print("Train samples: {}, test samples: {}".format(len(df), len(test_df)))
    df = df.append(test_df).reset_index()
    # Optional: Remove 4 applications with XNA CODE_GENDER (train set)
    df = df[df['CODE_GENDER'] != 'XNA']
    
    docs = [_f for _f in df.columns if 'FLAG_DOC' in _f]
    live = [_f for _f in df.columns if ('FLAG_' in _f) & ('FLAG_DOC' not in _f) & ('_FLAG_' not in _f)]
    
    # NaN values for DAYS_EMPLOYED: 365.243 -> nan
    df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)

    inc_by_org = df[['AMT_INCOME_TOTAL', 'ORGANIZATION_TYPE']].groupby('ORGANIZATION_TYPE').median()['AMT_INCOME_TOTAL']

    df['NEW_CREDIT_TO_ANNUITY_RATIO'] = df['AMT_CREDIT'] / df['AMT_ANNUITY']
    df['NEW_CREDIT_TO_GOODS_RATIO'] = df['AMT_CREDIT'] / df['AMT_GOODS_PRICE']
    df['NEW_DOC_IND_KURT'] = df[docs].kurtosis(axis=1)
    df['NEW_LIVE_IND_SUM'] = df[live].sum(axis=1)
    df['NEW_INC_PER_CHLD'] = df['AMT_INCOME_TOTAL'] / (1 + df['CNT_CHILDREN'])
    df['NEW_INC_BY_ORG'] = df['ORGANIZATION_TYPE'].map(inc_by_org)
    df['NEW_EMPLOY_TO_BIRTH_RATIO'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['NEW_ANNUITY_TO_INCOME_RATIO'] = df['AMT_ANNUITY'] / (1 + df['AMT_INCOME_TOTAL'])
    df['NEW_SOURCES_PROD'] = df['EXT_SOURCE_1'] * df['EXT_SOURCE_2'] * df['EXT_SOURCE_3']
    df['NEW_EXT_SOURCES_MEAN'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    df['NEW_SCORES_STD'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    df['NEW_SCORES_STD'] = df['NEW_SCORES_STD'].fillna(df['NEW_SCORES_STD'].mean())
    df['NEW_CAR_TO_BIRTH_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_BIRTH']
    df['NEW_CAR_TO_EMPLOY_RATIO'] = df['OWN_CAR_AGE'] / df['DAYS_EMPLOYED']
    df['NEW_PHONE_TO_BIRTH_RATIO'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_BIRTH']
    df['NEW_PHONE_TO_BIRTH_RATIO_EMPLOYER'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_EMPLOYED']
    df['NEW_CREDIT_TO_INCOME_RATIO'] = df['AMT_CREDIT'] / df['AMT_INCOME_TOTAL']
    
    # Categorical features with Binary encode (0 or 1; two categories)
    for bin_feature in ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']:
        df[bin_feature], uniques = pd.factorize(df[bin_feature])
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    dropcolum=['FLAG_DOCUMENT_2','FLAG_DOCUMENT_4',
    'FLAG_DOCUMENT_5','FLAG_DOCUMENT_6','FLAG_DOCUMENT_7',
    'FLAG_DOCUMENT_8','FLAG_DOCUMENT_9','FLAG_DOCUMENT_10', 
    'FLAG_DOCUMENT_11','FLAG_DOCUMENT_12','FLAG_DOCUMENT_13',
    'FLAG_DOCUMENT_14','FLAG_DOCUMENT_15','FLAG_DOCUMENT_16',
    'FLAG_DOCUMENT_17','FLAG_DOCUMENT_18','FLAG_DOCUMENT_19',
    'FLAG_DOCUMENT_20','FLAG_DOCUMENT_21']
    df= df.drop(dropcolum,axis=1)
    del test_df
    gc.collect()
    return df

# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(num_rows = None, nan_as_category = True):
    bureau = pd.read_csv('../data/bureau.csv', nrows = num_rows)
    bb = pd.read_csv('../data/bureau_balance.csv', nrows = num_rows)
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category)
    
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    del bb, bb_agg
    gc.collect()
    
    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': [ 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': [ 'mean'],
        'DAYS_CREDIT_UPDATE': ['mean'],
        'CREDIT_DAY_OVERDUE': ['mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM': [ 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': [ 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['mean'],
        'AMT_CREDIT_SUM_LIMIT': ['mean', 'sum'],
        'AMT_ANNUITY': ['max', 'mean'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum']
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
    
    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BURO_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    del active, active_agg
    gc.collect()
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    del closed, closed_agg, bureau
    gc.collect()
    return bureau_agg

# Preprocess previous_applications.csv
def previous_applications(num_rows = None, nan_as_category = True):
    prev = pd.read_csv('../data/previous_application.csv', nrows = num_rows)
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Days 365.243 values -> nan
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # Add feature: value ask / value received percentage
    prev['APP_CREDIT_PERC'] = prev['AMT_APPLICATION'] / prev['AMT_CREDIT']
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': [ 'max', 'mean'],
        'AMT_APPLICATION': [ 'max','mean'],
        'AMT_CREDIT': [ 'max', 'mean'],
        'APP_CREDIT_PERC': [ 'max', 'mean'],
        'AMT_DOWN_PAYMENT': [ 'max', 'mean'],
        'AMT_GOODS_PRICE': [ 'max', 'mean'],
        'HOUR_APPR_PROCESS_START': [ 'max', 'mean'],
        'RATE_DOWN_PAYMENT': [ 'max', 'mean'],
        'DAYS_DECISION': [ 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']
    
    prev_agg = prev.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    del refused, refused_agg, approved, approved_agg, prev
    gc.collect()
    return prev_agg

# Preprocess POS_CASH_balance.csv
def pos_cash(num_rows = None, nan_as_category = True):
    pos = pd.read_csv('../data/POS_CASH_balance.csv', nrows = num_rows)
    pos, cat_cols = one_hot_encoder(pos, nan_as_category= True)
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean', 'size'],
        'SK_DPD': ['max', 'mean'],
        'SK_DPD_DEF': ['max', 'mean']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    
    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    del pos
    gc.collect()
    return pos_agg
    
# Preprocess installments_payments.csv
def installments_payments(num_rows = None, nan_as_category = True):
    ins = pd.read_csv('../data/installments_payments.csv', nrows = num_rows)
    ins, cat_cols = one_hot_encoder(ins, nan_as_category= True)
    # Percentage and difference paid in each installment (amount paid and installment value)
    ins['PAYMENT_PERC'] = ins['AMT_PAYMENT'] / ins['AMT_INSTALMENT']
    ins['PAYMENT_DIFF'] = ins['AMT_INSTALMENT'] - ins['AMT_PAYMENT']
    # Days past due and days before due (no negative values)
    ins['DPD'] = ins['DAYS_ENTRY_PAYMENT'] - ins['DAYS_INSTALMENT']
    ins['DBD'] = ins['DAYS_INSTALMENT'] - ins['DAYS_ENTRY_PAYMENT']
    ins['DPD'] = ins['DPD'].apply(lambda x: x if x > 0 else 0)
    ins['DBD'] = ins['DBD'].apply(lambda x: x if x > 0 else 0)
    # Features: Perform aggregations
    aggregations = {
        'NUM_INSTALMENT_VERSION': ['nunique'],
        'DPD': ['max', 'mean', 'sum'],
        'DBD': ['max', 'mean', 'sum'],
        'PAYMENT_PERC': [ 'mean',  'var'],
        'PAYMENT_DIFF': [ 'mean', 'var'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum'],
        'AMT_PAYMENT': ['min', 'max', 'mean', 'sum'],
        'DAYS_ENTRY_PAYMENT': ['max', 'mean', 'sum']
    }
    for cat in cat_cols:
        aggregations[cat] = ['mean']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INSTAL_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    del ins
    gc.collect()
    return ins_agg

# Preprocess credit_card_balance.csv
def credit_card_balance(num_rows = None, nan_as_category = True):
    cc = pd.read_csv('../data/credit_card_balance.csv', nrows = num_rows)
    cc, cat_cols = one_hot_encoder(cc, nan_as_category= True)
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg([ 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    del cc
    gc.collect()
    return cc_agg

# %%
num_rows = 10000 if debug else None
df = application_train_test(num_rows)
with timer("Process bureau and bureau_balance"):
    bureau = bureau_and_balance(num_rows)
    print("Bureau df shape:", bureau.shape)
    df = df.join(bureau, how='left', on='SK_ID_CURR')
    del bureau
    gc.collect()
with timer("Process previous_applications"):
    prev = previous_applications(num_rows)
    print("Previous applications df shape:", prev.shape)
    df = df.join(prev, how='left', on='SK_ID_CURR')
    del prev
    gc.collect()
with timer("Process POS-CASH balance"):
    pos = pos_cash(num_rows)
    print("Pos-cash balance df shape:", pos.shape)
    df = df.join(pos, how='left', on='SK_ID_CURR')
    del pos
    gc.collect()
with timer("Process installments payments"):
    ins = installments_payments(num_rows)
    print("Installments payments df shape:", ins.shape)
    df = df.join(ins, how='left', on='SK_ID_CURR')
    del ins
    gc.collect()
with timer("Process credit card balance"):
    cc = credit_card_balance(num_rows)
    print("Credit card balance df shape:", cc.shape)
    df = df.join(cc, how='left', on='SK_ID_CURR')
    del cc
    gc.collect()
# Out:
# Train samples: 307511, test samples: 48744
# Bureau df shape: (305811, 95)
# Process bureau and bureau_balance - done in 19s
#
#
# Previous applications df shape: (338857, 219)
# Process previous_applications - done in 19s
#
#
# Pos-cash balance df shape: (337252, 18)
# Process POS-CASH balance - done in 11s
#
#
# Installments payments df shape: (339587, 22)
# Process installments payments - done in 25s
#
#
# Credit card balance df shape: (103558, 113)
# Process credit card balance - done in 14s

# %%
df.TARGET.value_counts()
# Out:
# 0.0    282682
# 1.0     24825
# Name: TARGET, dtype: int64

# %%
282682/24825
# Out:
# 11.386988922457201

# %%
debug = False
random_seed = 2019
submission_file_name = "submit_pub_kern_v3.csv"

# LightGBM GBDT with KFold or Stratified KFold
# Parameters from Tilii kernel: https://www.kaggle.com/tilii7/olivier-lightgbm-parameters-by-bayesian-opt/code
def kfold_lightgbm(df, num_folds, stratified = False, debug= False):
    # Divide in training/validation and test data
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=random_seed)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=random_seed)
    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        # LightGBM parameters found by Bayesian optimization
        clf = LGBMClassifier(
            nthread=0,
            #is_unbalance=True,
            n_estimators=10000,
            learning_rate=0.02,
            num_leaves=32,
            colsample_bytree=0.9497036,
            subsample=0.8715623,
            max_depth=8,
            reg_alpha=0.04,
            reg_lambda=0.073,
            min_split_gain=0.0222415,
            min_child_weight=40,
            silent=-1,
            verbose=-1,
            #scale_pos_weight=11
#             nthread=0,
# #             feature_fraction = 0.75,
# #             bagging_fraction = 0.75,
# #             bagging_freq = 2,
# #             min_data_in_leaf = 30,
#             #is_unbalance=True,
#             num_iterations=10000,
#             learning_rate=0.02,
#             num_leaves=32, ### 32
#             colsample_bytree=0.9497036,
#             subsample=0.8715623,
#             max_depth=8,
#             reg_alpha=0.04,
#             reg_lambda=0.073,
#             min_split_gain=0.0222415,
#             min_child_weight=40,
#             silent=-1,
#             verbose=-1,
#             scale_pos_weight=11.3
            )

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y),
                                            (valid_x, valid_y)],
                                            eval_metric= 'auc',
                                            verbose= 50,
                                            early_stopping_rounds= 200)

        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]
        sub_preds += clf.predict_proba(test_df[feats], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))
        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()

    print('Full AUC score %.6f' % roc_auc_score(train_df['TARGET'], oof_preds))
    # Write submission file and plot feature importance
    if not debug:
        test_df['TARGET'] = sub_preds
        test_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)
    display_importances(feature_importance_df)
    return feature_importance_df

# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances01.png')

# %%
with timer("Run LightGBM with kfold"):
    feat_importance = kfold_lightgbm(df, num_folds= 5, stratified= True, debug= debug)
# Out:
# Starting LightGBM. Train shape: (307507, 707), test shape: (48744, 707)
# Training until validation scores don't improve for 200 rounds.
# [50]	training's auc: 0.748703	valid_1's auc: 0.737031
# [100]	training's auc: 0.758351	valid_1's auc: 0.744605
# [150]	training's auc: 0.769921	valid_1's auc: 0.753327
# [200]	training's auc: 0.781607	valid_1's auc: 0.761752
# [250]	training's auc: 0.791993	valid_1's auc: 0.768868
# [300]	training's auc: 0.800087	valid_1's auc: 0.773352
# [350]	training's auc: 0.806466	valid_1's auc: 0.776533
# [400]	training's auc: 0.811959	valid_1's auc: 0.778686
# [450]	training's auc: 0.816891	valid_1's auc: 0.780246
# [500]	training's auc: 0.821506	valid_1's auc: 0.781573
# [550]	training's auc: 0.825728	valid_1's auc: 0.782575
# [600]	training's auc: 0.82957	valid_1's auc: 0.783384
# [650]	training's auc: 0.833498	valid_1's auc: 0.784209
# [700]	training's auc: 0.837111	valid_1's auc: 0.78471
# [750]	training's auc: 0.840603	valid_1's auc: 0.785169
# [800]	training's auc: 0.843904	valid_1's auc: 0.785621
# [850]	training's auc: 0.846991	valid_1's auc: 0.785995
# [900]	training's auc: 0.850137	valid_1's auc: 0.786375
# [950]	training's auc: 0.852939	valid_1's auc: 0.786627
# [1000]	training's auc: 0.85575	valid_1's auc: 0.786896
# [1050]	training's auc: 0.85849	valid_1's auc: 0.787058
# [1100]	training's auc: 0.861152	valid_1's auc: 0.787466
# [1150]	training's auc: 0.863858	valid_1's auc: 0.78761
# [1200]	training's auc: 0.866209	valid_1's auc: 0.787711
# [1250]	training's auc: 0.868809	valid_1's auc: 0.787851
# [1300]	training's auc: 0.871318	valid_1's auc: 0.787902
# [1350]	training's auc: 0.873866	valid_1's auc: 0.788059
# [1400]	training's auc: 0.876166	valid_1's auc: 0.788185
# [1450]	training's auc: 0.878611	valid_1's auc: 0.788216
# [1500]	training's auc: 0.880794	valid_1's auc: 0.788363
# [1550]	training's auc: 0.883061	valid_1's auc: 0.788444
# [1600]	training's auc: 0.885285	valid_1's auc: 0.788473
# [1650]	training's auc: 0.887227	valid_1's auc: 0.788594
# [1700]	training's auc: 0.889312	valid_1's auc: 0.788659
# [1750]	training's auc: 0.891475	valid_1's auc: 0.78867
# [1800]	training's auc: 0.893457	valid_1's auc: 0.788798
# [1850]	training's auc: 0.895495	valid_1's auc: 0.788847
# [1900]	training's auc: 0.897537	valid_1's auc: 0.788903
# [1950]	training's auc: 0.899332	valid_1's auc: 0.788847
# [2000]	training's auc: 0.901229	valid_1's auc: 0.788921
# [2050]	training's auc: 0.903145	valid_1's auc: 0.789045
# [2100]	training's auc: 0.905005	valid_1's auc: 0.789137
# [2150]	training's auc: 0.90666	valid_1's auc: 0.789119
# [2200]	training's auc: 0.908342	valid_1's auc: 0.789107
# [2250]	training's auc: 0.909911	valid_1's auc: 0.789102
# [2300]	training's auc: 0.911545	valid_1's auc: 0.789124
# [2350]	training's auc: 0.913254	valid_1's auc: 0.789006
# [2400]	training's auc: 0.914809	valid_1's auc: 0.789103
# [2450]	training's auc: 0.916531	valid_1's auc: 0.789105
# Early stopping, best iteration is:
# [2287]	training's auc: 0.911127	valid_1's auc: 0.789178
# Fold  1 AUC : 0.789178
# Training until validation scores don't improve for 200 rounds.
# [50]	training's auc: 0.747636	valid_1's auc: 0.745342
# [100]	training's auc: 0.756489	valid_1's auc: 0.752047
# [150]	training's auc: 0.76873	valid_1's auc: 0.760673
# [200]	training's auc: 0.780504	valid_1's auc: 0.768459
# [250]	training's auc: 0.791089	valid_1's auc: 0.775402
# [300]	training's auc: 0.799233	valid_1's auc: 0.780072
# [350]	training's auc: 0.805786	valid_1's auc: 0.783116
# [400]	training's auc: 0.811389	valid_1's auc: 0.78523
# [450]	training's auc: 0.816469	valid_1's auc: 0.786806
# [500]	training's auc: 0.821215	valid_1's auc: 0.78828
# [550]	training's auc: 0.825444	valid_1's auc: 0.789436
# [600]	training's auc: 0.829428	valid_1's auc: 0.790283
# [650]	training's auc: 0.833313	valid_1's auc: 0.791034
# [700]	training's auc: 0.836919	valid_1's auc: 0.791536
# [750]	training's auc: 0.840207	valid_1's auc: 0.792001
# [800]	training's auc: 0.843497	valid_1's auc: 0.792398
# [850]	training's auc: 0.846643	valid_1's auc: 0.792815
# [900]	training's auc: 0.849652	valid_1's auc: 0.793004
# [950]	training's auc: 0.852599	valid_1's auc: 0.793312
# [1000]	training's auc: 0.855312	valid_1's auc: 0.793499
# [1050]	training's auc: 0.858133	valid_1's auc: 0.793708
# [1100]	training's auc: 0.860878	valid_1's auc: 0.793738
# [1150]	training's auc: 0.863661	valid_1's auc: 0.793993
# [1200]	training's auc: 0.866304	valid_1's auc: 0.794121
# [1250]	training's auc: 0.868759	valid_1's auc: 0.794212
# [1300]	training's auc: 0.871083	valid_1's auc: 0.794212
# [1350]	training's auc: 0.873419	valid_1's auc: 0.794295
# [1400]	training's auc: 0.875652	valid_1's auc: 0.794303
# [1450]	training's auc: 0.877938	valid_1's auc: 0.794361
# [1500]	training's auc: 0.880161	valid_1's auc: 0.794352
# [1550]	training's auc: 0.882408	valid_1's auc: 0.794422
# [1600]	training's auc: 0.884412	valid_1's auc: 0.794481
# [1650]	training's auc: 0.886657	valid_1's auc: 0.794506
# [1700]	training's auc: 0.888675	valid_1's auc: 0.794545
# [1750]	training's auc: 0.890794	valid_1's auc: 0.794645
# [1800]	training's auc: 0.892679	valid_1's auc: 0.794728
# [1850]	training's auc: 0.89466	valid_1's auc: 0.79481
# [1900]	training's auc: 0.896369	valid_1's auc: 0.794878
# [1950]	training's auc: 0.898294	valid_1's auc: 0.794766
# [2000]	training's auc: 0.90012	valid_1's auc: 0.794876
# [2050]	training's auc: 0.902	valid_1's auc: 0.794933
# [2100]	training's auc: 0.903816	valid_1's auc: 0.794946
# [2150]	training's auc: 0.90555	valid_1's auc: 0.794935
# [2200]	training's auc: 0.907449	valid_1's auc: 0.794925
# [2250]	training's auc: 0.909177	valid_1's auc: 0.794819
# Early stopping, best iteration is:
# [2062]	training's auc: 0.902449	valid_1's auc: 0.794973
# Fold  2 AUC : 0.794973
# Training until validation scores don't improve for 200 rounds.
# [50]	training's auc: 0.7487	valid_1's auc: 0.73642
# [100]	training's auc: 0.758661	valid_1's auc: 0.74374
# [150]	training's auc: 0.770471	valid_1's auc: 0.752228
# [200]	training's auc: 0.781706	valid_1's auc: 0.760131
# [250]	training's auc: 0.791917	valid_1's auc: 0.767362
# [300]	training's auc: 0.79993	valid_1's auc: 0.772317
# [350]	training's auc: 0.806402	valid_1's auc: 0.775946
# [400]	training's auc: 0.812086	valid_1's auc: 0.778575
# [450]	training's auc: 0.817271	valid_1's auc: 0.780809
# [500]	training's auc: 0.821935	valid_1's auc: 0.78241
# [550]	training's auc: 0.826218	valid_1's auc: 0.783441
# [600]	training's auc: 0.830131	valid_1's auc: 0.784393
# [650]	training's auc: 0.833946	valid_1's auc: 0.785217
# [700]	training's auc: 0.837689	valid_1's auc: 0.785931
# [750]	training's auc: 0.841103	valid_1's auc: 0.786534
# [800]	training's auc: 0.844243	valid_1's auc: 0.787027
# [850]	training's auc: 0.847565	valid_1's auc: 0.78745
# [900]	training's auc: 0.850693	valid_1's auc: 0.787847
# [950]	training's auc: 0.853685	valid_1's auc: 0.788219
# [1000]	training's auc: 0.856473	valid_1's auc: 0.788384
# [1050]	training's auc: 0.859232	valid_1's auc: 0.788572
# [1100]	training's auc: 0.861767	valid_1's auc: 0.788697
# [1150]	training's auc: 0.864464	valid_1's auc: 0.788766
# [1200]	training's auc: 0.867025	valid_1's auc: 0.788976
# [1250]	training's auc: 0.869618	valid_1's auc: 0.789118
# [1300]	training's auc: 0.872125	valid_1's auc: 0.789198
# [1350]	training's auc: 0.874454	valid_1's auc: 0.789322
# [1400]	training's auc: 0.876876	valid_1's auc: 0.789392
# [1450]	training's auc: 0.879048	valid_1's auc: 0.789503
# [1500]	training's auc: 0.881338	valid_1's auc: 0.789587
# [1550]	training's auc: 0.883773	valid_1's auc: 0.789701
# [1600]	training's auc: 0.885731	valid_1's auc: 0.789757
# [1650]	training's auc: 0.887796	valid_1's auc: 0.78974
# [1700]	training's auc: 0.889812	valid_1's auc: 0.789794
# [1750]	training's auc: 0.891913	valid_1's auc: 0.789896
# [1800]	training's auc: 0.89383	valid_1's auc: 0.789823
# [1850]	training's auc: 0.895615	valid_1's auc: 0.789836
# [1900]	training's auc: 0.897584	valid_1's auc: 0.789756
# Early stopping, best iteration is:
# [1735]	training's auc: 0.89129	valid_1's auc: 0.789911
# Fold  3 AUC : 0.789911
# Training until validation scores don't improve for 200 rounds.
# [50]	training's auc: 0.748709	valid_1's auc: 0.74482
# [100]	training's auc: 0.757454	valid_1's auc: 0.749945
# [150]	training's auc: 0.769229	valid_1's auc: 0.758268
# [200]	training's auc: 0.78072	valid_1's auc: 0.765971
# [250]	training's auc: 0.791027	valid_1's auc: 0.772623
# [300]	training's auc: 0.799417	valid_1's auc: 0.777155
# [350]	training's auc: 0.805987	valid_1's auc: 0.780328
# [400]	training's auc: 0.811739	valid_1's auc: 0.782652
# [450]	training's auc: 0.816715	valid_1's auc: 0.784184
# [500]	training's auc: 0.821389	valid_1's auc: 0.7853
# [550]	training's auc: 0.825678	valid_1's auc: 0.786336
# [600]	training's auc: 0.829481	valid_1's auc: 0.787016
# [650]	training's auc: 0.833275	valid_1's auc: 0.787793
# [700]	training's auc: 0.836794	valid_1's auc: 0.788328
# [750]	training's auc: 0.84027	valid_1's auc: 0.788849
# [800]	training's auc: 0.843668	valid_1's auc: 0.78945
# [850]	training's auc: 0.846883	valid_1's auc: 0.789786
# [900]	training's auc: 0.849728	valid_1's auc: 0.789938
# [950]	training's auc: 0.852628	valid_1's auc: 0.79023
# [1000]	training's auc: 0.855359	valid_1's auc: 0.790418
# [1050]	training's auc: 0.858272	valid_1's auc: 0.790605
# [1100]	training's auc: 0.860959	valid_1's auc: 0.790743
# [1150]	training's auc: 0.863763	valid_1's auc: 0.790716
# [1200]	training's auc: 0.866344	valid_1's auc: 0.790902
# [1250]	training's auc: 0.868757	valid_1's auc: 0.790931
# [1300]	training's auc: 0.871226	valid_1's auc: 0.791091
# [1350]	training's auc: 0.873561	valid_1's auc: 0.79108
# [1400]	training's auc: 0.875853	valid_1's auc: 0.791036
# [1450]	training's auc: 0.878096	valid_1's auc: 0.791228
# [1500]	training's auc: 0.880215	valid_1's auc: 0.791346
# [1550]	training's auc: 0.882583	valid_1's auc: 0.791407
# [1600]	training's auc: 0.884725	valid_1's auc: 0.79139
# [1650]	training's auc: 0.886825	valid_1's auc: 0.791368
# [1700]	training's auc: 0.888886	valid_1's auc: 0.791324
# [1750]	training's auc: 0.890819	valid_1's auc: 0.791296
# Early stopping, best iteration is:
# [1578]	training's auc: 0.883745	valid_1's auc: 0.791455
# Fold  4 AUC : 0.791455
# Training until validation scores don't improve for 200 rounds.
# [50]	training's auc: 0.748527	valid_1's auc: 0.73909
# [100]	training's auc: 0.757197	valid_1's auc: 0.745354
# [150]	training's auc: 0.769103	valid_1's auc: 0.755001
# [200]	training's auc: 0.781049	valid_1's auc: 0.763858
# [250]	training's auc: 0.791351	valid_1's auc: 0.770866
# [300]	training's auc: 0.799228	valid_1's auc: 0.775589
# [350]	training's auc: 0.805888	valid_1's auc: 0.779069
# [400]	training's auc: 0.811548	valid_1's auc: 0.781531
# [450]	training's auc: 0.816438	valid_1's auc: 0.783341
# [500]	training's auc: 0.821173	valid_1's auc: 0.784905
# [550]	training's auc: 0.825484	valid_1's auc: 0.786123
# [600]	training's auc: 0.829346	valid_1's auc: 0.786962
# [650]	training's auc: 0.833053	valid_1's auc: 0.787816
# [700]	training's auc: 0.836638	valid_1's auc: 0.788545
# [750]	training's auc: 0.840279	valid_1's auc: 0.789221
# [800]	training's auc: 0.843678	valid_1's auc: 0.789716
# [850]	training's auc: 0.846754	valid_1's auc: 0.790052
# [900]	training's auc: 0.849748	valid_1's auc: 0.790293
# [950]	training's auc: 0.852765	valid_1's auc: 0.790585
# [1000]	training's auc: 0.855761	valid_1's auc: 0.79101
# [1050]	training's auc: 0.858538	valid_1's auc: 0.791313
# [1100]	training's auc: 0.861086	valid_1's auc: 0.791492
# [1150]	training's auc: 0.863893	valid_1's auc: 0.791676
# [1200]	training's auc: 0.866728	valid_1's auc: 0.791803
# [1250]	training's auc: 0.869205	valid_1's auc: 0.791938
# [1300]	training's auc: 0.871704	valid_1's auc: 0.792086
# [1350]	training's auc: 0.874077	valid_1's auc: 0.792179
# [1400]	training's auc: 0.87637	valid_1's auc: 0.792281
# [1450]	training's auc: 0.878536	valid_1's auc: 0.792383
# [1500]	training's auc: 0.880697	valid_1's auc: 0.792472
# [1550]	training's auc: 0.882906	valid_1's auc: 0.792529
# [1600]	training's auc: 0.885044	valid_1's auc: 0.792632
# [1650]	training's auc: 0.887205	valid_1's auc: 0.792654
# [1700]	training's auc: 0.889211	valid_1's auc: 0.792787
# [1750]	training's auc: 0.891138	valid_1's auc: 0.792707
# [1800]	training's auc: 0.893099	valid_1's auc: 0.792708
# [1850]	training's auc: 0.895091	valid_1's auc: 0.792659
# Early stopping, best iteration is:
# [1689]	training's auc: 0.888781	valid_1's auc: 0.792828
# Fold  5 AUC : 0.792828
# Full AUC score 0.791619
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Run LightGBM with kfold - done in 1069s

# %%
df_v3 = pd.read_csv('./submit_pub_kern_v3.csv', index_col='SK_ID_CURR')

# %%
df_v4 = pd.read_csv('./submit_pub_kern_v4.csv', index_col='SK_ID_CURR')

# %%
df_v5 = (df_v3 + df_v4)/2

# %%
df_v3
# Out:
#               TARGET
# SK_ID_CURR
# 100001      0.023983
# 100005      0.140384
# 100013      0.027257
# 100028      0.037368
# 100038      0.146592
# 100042      0.044775
# 100057      0.005269
# 100065      0.029164
# 100066      0.008205
# 100067      0.073300
# 100074      0.061963
# 100090      0.024443
# 100091      0.162785
# 100092      0.041506
# 100106      0.044729
# 100107      0.176682
# 100109      0.040266
# 100117      0.022535
# 100128      0.101439
# 100141      0.029099
# 100150      0.031619
# 100168      0.010954
# 100169      0.036944
# 100170      0.264829
# 100171      0.074110
# 100172      0.108901
# 100184      0.096779
# 100187      0.077618
# 100212      0.025457
# 100222      0.045555
# ...              ...
# 455963      0.025849
# 455965      0.013612
# 456007      0.157449
# 456008      0.014485
# 456009      0.027840
# 456010      0.116235
# 456011      0.026462
# 456013      0.276915
# 456028      0.123056
# 456058      0.101967
# 456111      0.077613
# 456114      0.077408
# 456115      0.028726
# 456116      0.011924
# 456119      0.008797
# 456120      0.126259
# 456122      0.072681
# 456123      0.024414
# 456166      0.090040
# 456167      0.039419
# 456168      0.029859
# 456169      0.106562
# 456170      0.010215
# 456189      0.135125
# 456202      0.070513
# 456221      0.060850
# 456222      0.056211
# 456223      0.010117
# 456224      0.026116
# 456250      0.223571
#
# [48744 rows x 1 columns]

# %%
df_v5
# Out:
#               TARGET
# SK_ID_CURR
# 100001      0.023786
# 100005      0.137242
# 100013      0.023629
# 100028      0.037072
# 100038      0.145648
# 100042      0.044795
# 100057      0.005153
# 100065      0.028891
# 100066      0.007951
# 100067      0.076858
# 100074      0.060021
# 100090      0.025150
# 100091      0.155694
# 100092      0.043997
# 100106      0.047229
# 100107      0.176601
# 100109      0.041445
# 100117      0.022995
# 100128      0.095424
# 100141      0.031141
# 100150      0.030123
# 100168      0.010548
# 100169      0.039385
# 100170      0.281749
# 100171      0.070119
# 100172      0.104508
# 100184      0.094131
# 100187      0.073232
# 100212      0.025861
# 100222      0.046626
# ...              ...
# 455963      0.026386
# 455965      0.013323
# 456007      0.160418
# 456008      0.014345
# 456009      0.030025
# 456010      0.112657
# 456011      0.025844
# 456013      0.274930
# 456028      0.124562
# 456058      0.100136
# 456111      0.075142
# 456114      0.076714
# 456115      0.029976
# 456116      0.011815
# 456119      0.008761
# 456120      0.131572
# 456122      0.068506
# 456123      0.025240
# 456166      0.093978
# 456167      0.038332
# 456168      0.030296
# 456169      0.107335
# 456170      0.010349
# 456189      0.138376
# 456202      0.069909
# 456221      0.063748
# 456222      0.057594
# 456223      0.009886
# 456224      0.025229
# 456250      0.231243
#
# [48744 rows x 1 columns]

# %%
df_v5.to_csv('./submit_pub_kern_v5.csv', index=True)

# %%
df_v5 = pd.read_csv('./submit_pub_kern_v5.csv')

# %%
df_v5
# Out:
#        SK_ID_CURR    TARGET
# 0          100001  0.023786
# 1          100005  0.137242
# 2          100013  0.023629
# 3          100028  0.037072
# 4          100038  0.145648
# 5          100042  0.044795
# 6          100057  0.005153
# 7          100065  0.028891
# 8          100066  0.007951
# 9          100067  0.076858
# 10         100074  0.060021
# 11         100090  0.025150
# 12         100091  0.155694
# 13         100092  0.043997
# 14         100106  0.047229
# 15         100107  0.176601
# 16         100109  0.041445
# 17         100117  0.022995
# 18         100128  0.095424
# 19         100141  0.031141
# 20         100150  0.030123
# 21         100168  0.010548
# 22         100169  0.039385
# 23         100170  0.281749
# 24         100171  0.070119
# 25         100172  0.104508
# 26         100184  0.094131
# 27         100187  0.073232
# 28         100212  0.025861
# 29         100222  0.046626
# ...           ...       ...
# 48714      455963  0.026386
# 48715      455965  0.013323
# 48716      456007  0.160418
# 48717      456008  0.014345
# 48718      456009  0.030025
# 48719      456010  0.112657
# 48720      456011  0.025844
# 48721      456013  0.274930
# 48722      456028  0.124562
# 48723      456058  0.100136
# 48724      456111  0.075142
# 48725      456114  0.076714
# 48726      456115  0.029976
# 48727      456116  0.011815
# 48728      456119  0.008761
# 48729      456120  0.131572
# 48730      456122  0.068506
# 48731      456123  0.025240
# 48732      456166  0.093978
# 48733      456167  0.038332
# 48734      456168  0.030296
# 48735      456169  0.107335
# 48736      456170  0.010349
# 48737      456189  0.138376
# 48738      456202  0.069909
# 48739      456221  0.063748
# 48740      456222  0.057594
# 48741      456223  0.009886
# 48742      456224  0.025229
# 48743      456250  0.231243
#
# [48744 rows x 2 columns]
